# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/ronholzapfel/Documents/dac-migration-dss-popupsim/results/coarse_run_h4r_01.csv")
# Out:
# /var/folders/_r/9n6ndj_d7k5b5yds9vn86n200000gn/T/ipykernel_14644/1602703423.py:1: DtypeWarning: Columns (0: ctr_r0_condition, 1: ctr_r1_condition) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/Users/ronholzapfel/Documents/dac-migration-dss-popupsim/results/coarse_run_h4r_01.csv")

# %%
df.head()
# Out:
#    ctr_base_priority  ctr_n_rules ctr_hold_condition  ctr_hold_threshold  \
# 0                  1            0                NaN                 NaN
# 1                  1            0                NaN                 NaN
# 2                  1            0                NaN                 NaN
# 3                  1            0                NaN                 NaN
# 4                  1            0                NaN                 NaN
#
#    ctr_max_hold_time ctr_r0_condition  ctr_r0_threshold  ctr_r0_priority  \
# 0                NaN              NaN               NaN              NaN
# 1                NaN              NaN               NaN              NaN
# 2                NaN              NaN               NaN              NaN
# 3                NaN              NaN               NaN              NaN
# 4                NaN              NaN               NaN              NaN
#
#   ctr_r1_condition  ctr_r1_threshold  ...  retrofitted_selection_strategy  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 71993 entries, 0 to 71992
# Data columns (total 92 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ctr_base_priority               71993 non-null  int64
#  1   ctr_n_rules                     71993 non-null  int64
#  2   ctr_hold_condition              56873 non-null  str
#  3   ctr_hold_threshold              56873 non-null  float64
#  4   ctr_max_hold_time               28080 non-null  float64
#  5   ctr_r0_condition                61193 non-null  str
#  6   ctr_r0_threshold                61193 non-null  float64
#  7   ctr_r0_priority                 61193 non-null  float64
#  8   ctr_r1_condition                21600 non-null  str
#  9   ctr_r1_threshold                21600 non-null  float64
#  10  ctr_r1_priority                 21600 non-null  float64
#  11  ctr_r2_condition                0 non-null      float64
# ...

# %%
df.sort_values(by="wagon_completion_pct", ascending=False).head()
# Out:
#        ctr_base_priority  ctr_n_rules ctr_hold_condition  ctr_hold_threshold  \
# 42848                  1            1  target_fill_below                0.85
# 66476                  1            1                NaN                 NaN
# 35517                  1            1  target_fill_below                0.70
# 39837                  1            1  target_fill_below                0.85
# 10450                  1            0  target_fill_below                0.85
#
#        ctr_max_hold_time   ctr_r0_condition  ctr_r0_threshold  \
# 42848               30.0  source_fill_above               0.4
# 66476                NaN  source_fill_above               0.7
# 35517                NaN  source_fill_above               0.4
# 39837                NaN  source_fill_above               0.4
# 10450               30.0                NaN               NaN
#
#        ctr_r0_priority ctr_r1_condition  ctr_r1_threshold  ...  \
# ...

# %%
import sys
sys.path.insert(0, 'popupsim/backend/src')

from pathlib import Path
from popupsim.optimizer.runner import row_to_configuration

CSV_PATH = Path("/Users/ronholzapfel/Documents/dac-migration-dss-popupsim/results/coarse_run_h4r_01.csv")
ROW = 10937  # change to any 0-based row index

cfg = row_to_configuration(CSV_PATH, ROW)
print(cfg.model_dump_json(indent=2))
# Out:
# {
#   "tracks": [],
#   "task_priorities": {
#     "collection_to_retrofit": {
#       "base_priority": 1,
#       "rules": [
#         {
#           "condition": "source_fill_above",
#           "threshold": 0.7,
#           "priority": 0
#         }
#       ],
#       "hold_until": null,
#       "max_hold_time": null
#     },
#     "retrofit_to_workshop": {
#       "base_priority": 2,
#       "rules": [],
#       "hold_until": null,
#       "max_hold_time": null
#     },
#     "workshop_to_retrofitted": {
#       "base_priority": 2,
#       "rules": [],
#       "hold_until": null,
#       "max_hold_time": null
#     },
#     "retrofitted_to_parking": {
#       "base_priority": 3,
#       "rules": [],
#       "hold_until": {
#         "condition": "source_fill_above",
#         "threshold": 0.35
#       },
#       "max_hold_time": null
#     }
#   },
#   "collection_track_strategy": "first_available",
#   "retrofit_selection_strategy": "least_occupied",
# ...
